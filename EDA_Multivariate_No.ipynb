# %% [markdown]
# # Proyecto 1
#
# **Tema:** Predicción de enfermedades Cardíacas
#
#
#
# |     Nombres      |      Apellidos       |     Login     |  Codigo   |
# | :--------------: | :------------------: | :-----------: | :-------: |
# |     Santiago     | Gonzalez Montealegre | s.gonzalez35  | 202012274 |
# | Juliana Carolina |  Cardenas Barragan   | jc.cardenasb1 | 202011683 |

# %% [markdown]
# ## Exploratory Data Analysis
# ### Two or more Variables

# %% [markdown]
# ## Summary
#
# Tenemos dos grupos de variables: las numéricas y las categóricas. Además, una variable _target_ a estudiar.
#
#
# ### Variables Numéricas
#
# - Edad (age)
# - Presión Arterial en Reposo (trestbps)
# - Colesterol Sérico (chol)
# - Frecuencia Cardiaca Máxima (thalach)
# - Depresion del ST Inducida por Ejercicio en Relación con Reposo (oldpeak)
#
# ### Variables Categóricas
#
# - Sexo (sex)
# - Tipo de Dolor en Pecho (cp)
# - Azucar en Sange en Ayunas (fbs)
# - Resultados Electrocardiográficos en Reposo (restecg)
# - Angina Inducida por Ejercicio (exang)
# - Pendiente Segmento ST de Ejercicio Máximo (slope)
# - Número de Vasos Principales coloreados por Fluoroscopia (ca)
# - Thalassemia (thal)
#
#
# ### Target
#
# - Presencia de Enfermedad Cardiaca (heartdis)

# %% [markdown]
# ### Libraries required

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = {
    "age": {'meaning': 'age in years',
            'num': 3},
    "sex": {'meaning': 'sex (1 = male; 0 = female)',
            'num': 4},
    "cp": {'meaning': 'chest pain type 1: typical angina; 2: atypical angina; 3: non-anginal pain; 4: asymptomatic',
           'num': 9},
    "trestbps": {'meaning': 'resting blood pressure (in mm Hg on admission to the hospital)',
                 'num': 10},
    "chol": {'meaning': 'serum cholestoral in mg/dl',
             'num': 12},
    "fbs": {'meaning': '(fasting blood sugar > 120 mg/dl)  (1 = true; 0 = false)',
            'num': 16},
    "restecg": {'meaning': 'resting electrocardiographic results 0: normal; 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV); 2: showing probable or definite left ventricular hypertrophy by Estes criteria',
                'num': 19},
    "thalach": {'meaning': 'maximum heart rate achieved',
                'num': 32},
    "exang": {'meaning': 'exercise induced angina (1 = yes; 0 = no)',
              'num': 38},
    "oldpeak": {'meaning': 'ST depression induced by exercise relative to rest',
                'num': 40},
    "slope": {'meaning': 'the slope of the peak exercise ST segment 1: upsloping; 2: flat; 3: downsloping',
              'num': 41},
    "ca": {'meaning': 'number of major vessels (0-3) colored by flourosopy',
           'num': 44},
    "thal": {'meaning': '3 = normal; 6 = fixed defect; 7 = reversable defect',
             'num': 51},
    "num": {'meaning': 'diagnosis of heart disease (angiographic disease status) 0: < 50% diameter narrowing; 1: > 50% diameter narrowing',
            'num': 58},
}

df = pd.read_csv("Data/processed.cleveland.data", names=[i for i in columns.keys()])

df.age = df.age.astype(int)
df.sex = df.sex.astype(int)
df.cp = df.cp.astype(int)
df.trestbps = df.trestbps.astype(int)
df.chol = df.chol.astype(int)
df.fbs = df.fbs.astype(int)
df.restecg = df.restecg.astype(int)
df.thalach = df.thalach.astype(int)
df.exang = df.exang.astype(int)
df.slope = df.slope.astype(int)

# ------------
# Null values
# ------------

df['caNull'] = df['ca']
df.loc[df['caNull'] == '?', 'ca'] = float(df.ca.mode()[0])
df.loc[df['caNull'] != '?', 'ca'] = df['ca']
df['ca'] = pd.to_numeric(df['ca']).astype('int32')

df['thalNull'] = df['thal']
df.loc[df['thalNull'] == '?', 'thal'] = float(df.thal.mode()[0])
df.loc[df['thalNull'] != '?', 'thal'] = df['thal']
df['thal'] = pd.to_numeric(df['thal']).astype('int32')

# ------------
# Target
# ------------

df.loc[df['num'] == 0, 'heartdis'] = 0
df.loc[df['num'] != 0, 'heartdis'] = 1
df.heartdis = df.heartdis.astype(int)

# ------------
# Drop columns
# ------------
df.drop(['num', 'caNull', 'thalNull'], axis=1, inplace=True)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope  ca  thal  heartdis
# 0        3   0     6         0
# 1        2   3     3         1
# 2        2   2     7         1
# 3        3   0     3         0
# 4        1   0     3         0
# ..     ...  ..   ...       ...
# 298      2   0     7         1
# 299      2   2     7         1
# 300      2   1     7         1
# 301      2   1     3         1
# 302      1   0     3         0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Correlations Matrix

# %%
corr = df.corr()
corr
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_62495_row0_col0, #T_62495_row1_col1, #T_62495_row2_col2, #T_62495_row3_col3, #T_62495_row4_col4, #T_62495_row5_col5, #T_62495_row6_col6, #T_62495_row7_col7, #T_62495_row8_col8, #T_62495_row9_col9, #T_62495_row10_col10, #T_62495_row11_col11, #T_62495_row12_col12, #T_62495_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_62495_row0_col1, #T_62495_row1_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_62495_row0_col2, #T_62495_row0_col3, #T_62495_row1_col9 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_62495_row0_col4, #T_62495_row0_col8, #T_62495_row6_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_62495_row0_col5, #T_62495_row8_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_62495_row0_col6, #T_62495_row1_col0, #T_62495_row3_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_62495_row0_col7, #T_62495_row7_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_62495_row0_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_62495_row0_col10, #T_62495_row3_col9, #T_62495_row13_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_62495_row0_col11 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_62495_row0_col12, #T_62495_row6_col11 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_62495_row0_col13 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_62495_row1_col2, #T_62495_row1_col7, #T_62495_row5_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_62495_row1_col3, #T_62495_row1_col4, #T_62495_row2_col5, #T_62495_row4_col1, #T_62495_row7_col0, #T_62495_row7_col2, #T_62495_row7_col6, #T_62495_row7_col8, #T_62495_row7_col9, #T_62495_row7_col10, #T_62495_row7_col11, #T_62495_row7_col12, #T_62495_row7_col13, #T_62495_row13_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_62495_row1_col6, #T_62495_row10_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_62495_row1_col8, #T_62495_row11_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_62495_row1_col10, #T_62495_row4_col2, #T_62495_row4_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_62495_row1_col11 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_62495_row1_col12 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_62495_row1_col13 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_62495_row2_col0, #T_62495_row11_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_62495_row2_col1, #T_62495_row5_col4, #T_62495_row11_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_62495_row2_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_62495_row2_col4, #T_62495_row4_col12 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_62495_row2_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_62495_row2_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_62495_row2_col8 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_62495_row2_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_62495_row2_col10, #T_62495_row6_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_62495_row2_col11 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_62495_row2_col12 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_62495_row2_col13, #T_62495_row13_col8 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_62495_row3_col0, #T_62495_row12_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_62495_row3_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_62495_row3_col2, #T_62495_row5_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_62495_row3_col4, #T_62495_row4_col10 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_62495_row3_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_62495_row3_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_62495_row3_col8, #T_62495_row3_col12, #T_62495_row5_col10, #T_62495_row5_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_62495_row3_col10 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_62495_row3_col11, #T_62495_row5_col7, #T_62495_row8_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_62495_row3_col13, #T_62495_row9_col2, #T_62495_row10_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_62495_row4_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_62495_row4_col3, #T_62495_row9_col6, #T_62495_row12_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_62495_row4_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_62495_row4_col6, #T_62495_row6_col7, #T_62495_row9_col3, #T_62495_row13_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_62495_row4_col7, #T_62495_row4_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_62495_row4_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_62495_row4_col13 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_62495_row5_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_62495_row5_col1, #T_62495_row9_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_62495_row5_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_62495_row5_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_62495_row5_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_62495_row5_col12 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_62495_row5_col13, #T_62495_row6_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_62495_row6_col1, #T_62495_row12_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_62495_row6_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_62495_row6_col3, #T_62495_row10_col1, #T_62495_row11_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_62495_row6_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_62495_row6_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_62495_row6_col10, #T_62495_row12_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_62495_row6_col12, #T_62495_row13_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_62495_row6_col13, #T_62495_row12_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_62495_row7_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_62495_row7_col4, #T_62495_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_62495_row7_col5, #T_62495_row8_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_62495_row8_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_62495_row8_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_62495_row8_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_62495_row8_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_62495_row8_col5, #T_62495_row13_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_62495_row8_col9, #T_62495_row8_col12 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_62495_row8_col10, #T_62495_row10_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_62495_row8_col11 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_62495_row8_col13 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_62495_row9_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_62495_row9_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_62495_row9_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_62495_row9_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_62495_row9_col8, #T_62495_row9_col12, #T_62495_row12_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_62495_row9_col10 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_62495_row9_col11, #T_62495_row12_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_62495_row9_col13 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_62495_row10_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_62495_row10_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_62495_row10_col6, #T_62495_row13_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_62495_row10_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_62495_row10_col9 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_6249

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="magma", fmt='.2f', vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ## Target VS All

# %% [markdown]
# ### Age

# %%
sns.boxplot(data=df, x='heartdis', y='age')
plt.show()

# %%
sns.violinplot(data=df, x='heartdis', y='age')
plt.show()

# %% [markdown]
# ### Sex

# %%
sns.countplot(data=df, x='heartdis', hue='sex')
plt.show()

# %% [markdown]
# ### Chest Pain

# %%
sns.countplot(data=df, x='heartdis', hue='cp')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='cp')
plt.show()

# %% [markdown]
# ### Resting Blood Pressure

# %%
sns.boxplot(data=df, x='heartdis', y='trestbps')
plt.show()

# %%
sns.violinplot(data=df, x='heartdis', y='trestbps')
plt.show()

# %% [markdown]
# ### Fasting Blood Sugar

# %%
sns.countplot(data=df, x='heartdis', hue='fbs')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='fbs')
plt.show()

# %% [markdown]
# ### Resting Electrocardiographic Results

# %%
sns.countplot(data=df, x='heartdis', hue='restecg')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='restecg')
plt.show()

# %% [markdown]
# ### Maximum Heart Rate

# %%
sns.boxplot(data=df, x='heartdis', y='thalach')
plt.show()

# %%
sns.violinplot(data=df, x='heartdis', y='thalach')
plt.show()

# %% [markdown]
# ### Exercise Induced Angina

# %%
sns.countplot(data=df, x='heartdis', hue='exang')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='exang')
plt.show()

# %% [markdown]
# ### ST Depression by Exercise

# %%
sns.boxplot(data=df, x='heartdis', y='oldpeak')
plt.show()

# %%
sns.violinplot(data=df, x='heartdis', y='oldpeak')
plt.show()

# %% [markdown]
# ### Slope in Peak Exercise

# %%
sns.countplot(data=df, x='heartdis', hue='slope')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='slope')
plt.show()

# %% [markdown]
# ### Number of Vessels Colored

# %%
sns.countplot(data=df, x='heartdis', hue='ca')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='ca')
plt.show()

# %% [markdown]
# ### Thalassemia

# %%
sns.countplot(data=df, x='heartdis', hue='thal')
plt.show()

# %%
sns.countplot(data=df, hue='heartdis', x='thal')
plt.show()

# %% [markdown]
# ## Numerical VS Numerical

# %%
import plotly.express as px

# %%
numdf = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'heartdis']]
fig = px.scatter_matrix(numdf, dimensions=['age', 'trestbps', 'chol', 'thalach', 'oldpeak'], opacity=0.7)
fig.update_traces(diagonal_visible=False)
fig.update_traces(marker=dict(size=4))
fig.show()

# %%
numdf = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'heartdis']].copy()
numdf['heartdisStr'] = numdf['heartdis'].astype(str)
fig = px.scatter_matrix(numdf, dimensions=['age', 'trestbps', 'chol', 'thalach', 'oldpeak'], color='heartdisStr', opacity=0.5)
fig.update_traces(diagonal_visible=False)
fig.update_traces(marker=dict(size=4))
fig.show()

# %%
numdf = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']]
pd.plotting.scatter_matrix(numdf, figsize=(15,15))
plt.show()

# %% [markdown]
# ### Age VS Trestbps

# %%
ax = df.plot.scatter(x='age', y='trestbps')
# Out:
# c:\Users\SGM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
ax = df.plot.hexbin(x='age', y='trestbps', sharex=False)

# %%
sns.kdeplot(data=df, x='age', y='trestbps')
# Out:
# <AxesSubplot: xlabel='age', ylabel='trestbps'>

# %% [markdown]
# Cierta pendiente positiva.

# %% [markdown]
# ### Age VS Chol

# %%
ax = df.plot.scatter(x='age', y='chol')
# Out:
# c:\Users\SGM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
ax = df.plot.hexbin(x='age', y='chol', sharex=False)

# %%
sns.kdeplot(data=df, x='age', y='chol')
# Out:
# <AxesSubplot: xlabel='age', ylabel='chol'>

# %% [markdown]
# ### Age VS Thalach

# %%
ax = df.plot.scatter(x='age', y='thalach')
# Out:
# c:\Users\SGM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
ax = df.plot.hexbin(x='age', y='thalach', sharex=False)

# %%
sns.kdeplot(data=df, x='age', y='thalach')
# Out:
# <AxesSubplot: xlabel='age', ylabel='thalach'>

# %% [markdown]
# ### Age VS Oldpeak

# %%
ax = df.plot.scatter(x='age', y='oldpeak')
# Out:
# c:\Users\SGM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
ax = df.plot.hexbin(x='age', y='oldpeak', sharex=False)

# %%
sns.kdeplot(data=df, x='age', y='oldpeak')
# Out:
# <AxesSubplot: xlabel='age', ylabel='oldpeak'>

# %% [markdown]
# ## Categorical VS Numerical

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="magma", fmt='.2f', vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ### Sex (sex)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'sex']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'sex']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')

plt.show()

# %% [markdown]
# ### Chest Pain (cp)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'cp']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'cp']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')

plt.show()

# %% [markdown]
# ### Fasting Blood Sugar (fbs)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'fbs']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'fbs']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')

plt.show()

# %% [markdown]
# ### Resting Electrocardiographic (restecg)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'restecg']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'restecg']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()

# %% [markdown]
# ### Exercise Induced Angina (exang)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'exang']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'exang']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()

# %% [markdown]
# ### Slope of Peak Exercise Segment (slope)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'slope']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'slope']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()

# %% [markdown]
# ### Majos Vassels colored by Flouroscopy (ca)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()

# %% [markdown]
# ### Thalassemia (thal)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'thal']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'thal']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()

# %% [markdown]
# ### Heart Disease (heartdis)

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'heartdis']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    data.boxplot(column=column, by=data.columns[-1], ax=ax) 
       
fig.subplots_adjust(hspace=0.7, wspace=0.3)
plt.show()

# %%
data = df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'heartdis']].copy()

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(8,8))

for ax, column in zip(axes.flatten(), data.columns):
    if column == data.columns[-1]:
        ax.set_visible(False)
        continue
    sns.violinplot(data=data, x=data.columns[-1], y=column, ax=ax, palette='rainbow')
    ax.set_title(column)
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {data.columns[-1]}')
plt.show()
